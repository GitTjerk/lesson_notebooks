# %%
google_api = "https://www.googleapis.com/customsearch/v1?"

# %%
params = {
    "key": "AIzaSyDeDEXWk7bq0r0GYzz-Pmc6dWqRGVxJ2Zc",
    "cx": "003240156206868727193:scrr7eqktoy",
    "fields": "kind,items(title,link,snippet),queries(request(title,totalResults,count,startIndex))",
    "q": "madrid",
    "start": 1
}

# %%
import requests
import json

# %%
response = requests.get(google_api, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
print(json.dumps(response.json(), sort_keys=True, indent=4))
# Out:
# {
#     "items": [
#         {
#             "link": "https://summit.ironhack.com/",
#             "snippet": "Enjoy a guided tour and discover some of the most popular places in Madrid. You\n'll also grab some beers in the city center. This is an optional activity, but you\u00a0...",
#             "title": "Ironhack Alumni Summit"
#         },
#         {
#             "link": "http://blog.ironhack.com/madrid-2/",
#             "snippet": "Jan 18, 2019 ... Our alumni Elise tells you all about her background, why she joined Ironhack, \nand her experience of the web dev bootcamp. read more\u00a0...",
#             "title": "Madrid | Ironhack Blog"
#         },
#         {
#             "link": "https://www.ironhack.com/fr/campus/madrid",
#             "snippet": "Formez vous sur Madrid en D\u00e9veloppement Web ou en UX/UI design gr\u00e2ce \u00e0 \nnos bootcamps \u00e0 temps plein ou temps partiel.",
#             "title": "Ironhack Madrid - Bootcamps en D\u00e9veloppement Web et UX/UI ..."
#         },
#         {
#             "link": "https://www.ironhack.com/",
#             "snippet": "Learn to code and UX/UI design through one of our full time or part time courses. \nWeb Development Bootcamp and UX/UI Design Bootcamp in Madrid,\u00a0...",
#             "title": "Ironhack Web Development Bootcamp & UX/UI Design Bootcamp"
#         },
#         {
#             "link": "https://blog.ironhack.com/category/madrid-en/",
#             "snippet": "Dec 3, 2018 ... Our latest articles Inside Cabify \u2013 Our alumni experience by Alberto Marcos | Aug \n1, 2016 | Alumni, Madrid At Ironhack, we like to interview\u00a0...",
#             "title": "Madrid Archives - Ironhack Blog"
#         },
#         {
#             "link": "https://blog.ironhack.com/es/madrid-2-2/page/3/",
#             "snippet": "In May this year, I was at a point in my life that many of you will identify with. I had \nbeen studying for the last 8 years of my life, architecture degree for 7 of them\u2026",
#             "title": "Madrid (ES) | Ironhack Blog"
#         },
#         {
#             "link": "https://blog.ironhack.com/es/campus-de-madrid/page/5/",
#             "snippet": "In May this year, I was at a point in my life that many of you will identify with. I had \nbeen studying for the last 8 years of my life, architecture degree for 7 of them\u2026",
#             "title": "Campus de Madrid - Ironhack Blog"
#         },
#         {
#             "link": "https://blog.ironhack.com/es/madrid-2-2/page/10/",
#             "snippet": "Building.co is a collaborative workspace that accommodates local tech \ncompanies; it also happens to be home to the Ironhack Miami campus. It's loved \nfor the\u00a0...",
#             "title": "Madrid (ES) | Ironhack Blog"
#         },
#         {
#             "link": "https://blog.ironhack.com/es/campus-de-madrid/page/12/",
#             "snippet": "First impressions count, and the window in which they're formed is usually small. \nThis is why we're mindful of every minute, from the moment the students walk\u00a0...",
#             "title": "Campus de Madrid - Ironhack Blog"
#         },
#         {
#             "link": "https://blog.ironhack.com/es/campus-de-madrid/page/10/",
#             "snippet": "Jimmy: Alright, so we are recording. Welcome back to another Ironhack Student \nPodcast, I am Jimmy. And in case you don't know what Ironhack is we are a\u00a0...",
#             "title": "Campus de Madrid - Ironhack Blog"
#         }
#     ],
#     "kind": "customsearch#search",
#     "queries": {
#         "request": [
#             {
#                 "count": 10,
#                 "startIndex": 1,
#                 "title": "Google Custom Search - madrid",
#                 "totalResults": "1670"
#             }
#         ]
#     }
# }

# %%
import pandas as pd

# %%
events = pd.DataFrame(response.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-791a35c79977> in <module>
# ----> 1 events = pd.DataFrame(response.json())
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in extract_index(data)
#    7403
#    7404             if have_dicts:
# -> 7405                 raise ValueError('Mixing dicts with non-Series may lead to '
#    7406                                  'ambiguous ordering.')
#    7407
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
data = response.json()

# %%
data['items']
# Out:
# [{'title': 'Ironhack Alumni Summit',
#   'link': 'https://summit.ironhack.com/',
#   'snippet': "Enjoy a guided tour and discover some of the most popular places in Madrid. You\n'll also grab some beers in the city center. This is an optional activity, but you\xa0..."},
#  {'title': 'Madrid | Ironhack Blog',
#   'link': 'http://blog.ironhack.com/madrid-2/',
#   'snippet': 'Jan 18, 2019 ... Our alumni Elise tells you all about her background, why she joined Ironhack, \nand her experience of the web dev bootcamp. read more\xa0...'},
#  {'title': 'Ironhack Madrid - Bootcamps en Développement Web et UX/UI ...',
#   'link': 'https://www.ironhack.com/fr/campus/madrid',
#   'snippet': 'Formez vous sur Madrid en Développement Web ou en UX/UI design grâce à \nnos bootcamps à temps plein ou temps partiel.'},
#  {'title': 'Ironhack Web Development Bootcamp & UX/UI Design Bootcamp',
#   'link': 'https://www.ironhack.com/',
#   'snippet': 'Learn to code and UX/UI design through one of our full time or part time courses. \nWeb Development Bootcamp and UX/UI Design Bootcamp in Madrid,\xa0...'},
#  {'title': 'Madrid Archives - Ironhack Blog',
#   'link': 'https://blog.ironhack.com/category/madrid-en/',
#   'snippet': 'Dec 3, 2018 ... Our latest articles Inside Cabify – Our alumni experience by Alberto Marcos | Aug \n1, 2016 | Alumni, Madrid At Ironhack, we like to interview\xa0...'},
#  {'title': 'Madrid (ES) | Ironhack Blog',
#   'link': 'https://blog.ironhack.com/es/madrid-2-2/page/3/',
#   'snippet': 'In May this year, I was at a point in my life that many of you will identify with. I had \nbeen studying for the last 8 years of my life, architecture degree for 7 of them…'},
#  {'title': 'Campus de Madrid - Ironhack Blog',
#   'link': 'https://blog.ironhack.com/es/campus-de-madrid/page/5/',
#   'snippet': 'In May this year, I was at a point in my life that many of you will identify with. I had \nbeen studying for the last 8 years of my life, architecture degree for 7 of them…'},
#  {'title': 'Madrid (ES) | Ironhack Blog',
#   'link': 'https://blog.ironhack.com/es/madrid-2-2/page/10/',
#   'snippet': "Building.co is a collaborative workspace that accommodates local tech \ncompanies; it also happens to be home to the Ironhack Miami campus. It's loved \nfor the\xa0..."},
#  {'title': 'Campus de Madrid - Ironhack Blog',
#   'link': 'https://blog.ironhack.com/es/campus-de-madrid/page/12/',
#   'snippet': "First impressions count, and the window in which they're formed is usually small. \nThis is why we're mindful of every minute, from the moment the students walk\xa0..."},
#  {'title': 'Campus de Madrid - Ironhack Blog',
#   'link': 'https://blog.ironhack.com/es/campus-de-madrid/page/10/',
#   'snippet': "Jimmy: Alright, so we are recording. Welcome back to another Ironhack Student \nPodcast, I am Jimmy. And in case you don't know what Ironhack is we are a\xa0..."}]

# %%
json_normalize(data, 'items', [ 'link', 'snippet', 'title'], errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-96f25ec7a4de> in <module>
# ----> 1 json_normalize(data, 'items', [ 'link', 'snippet', 'title'], errors='ignore')
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/json/normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     275         if k in result:
#     276             raise ValueError('Conflicting metadata name {name}, '
# --> 277                              'need distinguishing prefix '.format(name=k))
#     278
#     279         result[k] = np.array(v).repeat(lengths)
#
# ValueError: Conflicting metadata name link, need distinguishing prefix

# %%
events = pd.DataFrame(data['items'])

# %%
events
# Out:
#                                                 link  \
# 0                       https://summit.ironhack.com/
# 1                 http://blog.ironhack.com/madrid-2/
# 2          https://www.ironhack.com/fr/campus/madrid
# 3                          https://www.ironhack.com/
# 4      https://blog.ironhack.com/category/madrid-en/
# 5    https://blog.ironhack.com/es/madrid-2-2/page/3/
# 6  https://blog.ironhack.com/es/campus-de-madrid/...
# 7   https://blog.ironhack.com/es/madrid-2-2/page/10/
# 8  https://blog.ironhack.com/es/campus-de-madrid/...
# 9  https://blog.ironhack.com/es/campus-de-madrid/...
#
#                                              snippet  \
# 0  Enjoy a guided tour and discover some of the m...
# 1  Jan 18, 2019 ... Our alumni Elise tells you al...
# 2  Formez vous sur Madrid en Développement Web ou...
# 3  Learn to code and UX/UI design through one of ...
# 4  Dec 3, 2018 ... Our latest articles Inside Cab...
# 5  In May this year, I was at a point in my life ...
# 6  In May this year, I was at a point in my life ...
# 7  Building.co is a collaborative workspace that ...
# 8  First impressions count, and the window in whi...
# 9  Jimmy: Alright, so we are recording. Welcome b...
#
#                                                title
# 0                             Ironhack Alumni Summit
# 1                             Madrid | Ironhack Blog
# 2  Ironhack Madrid - Bootcamps en Développement W...
# 3  Ironhack Web Development Bootcamp & UX/UI Desi...
# 4                    Madrid Archives - Ironhack Blog
# 5                        Madrid (ES) | Ironhack Blog
# 6                   Campus de Madrid - Ironhack Blog
# 7                        Madrid (ES) | Ironhack Blog
# 8                   Campus de Madrid - Ironhack Blog
# 9                   Campus de Madrid - Ironhack Blog

# %%
events.groupby(['snippet']).count()
# Out:
#                                                     link  title
# snippet
# Building.co is a collaborative workspace that a...     1      1
# Dec 3, 2018 ... Our latest articles Inside Cabi...     1      1
# Enjoy a guided tour and discover some of the mo...     1      1
# First impressions count, and the window in whic...     1      1
# Formez vous sur Madrid en Développement Web ou ...     1      1
# In May this year, I was at a point in my life t...     2      2
# Jan 18, 2019 ... Our alumni Elise tells you all...     1      1
# Jimmy: Alright, so we are recording. Welcome ba...     1      1
# Learn to code and UX/UI design through one of o...     1      1

# %%
events.shape
# Out:
# (10, 3)

# %%
events
# Out:
#                                                 link  \
# 0                       https://summit.ironhack.com/
# 1                 http://blog.ironhack.com/madrid-2/
# 2          https://www.ironhack.com/fr/campus/madrid
# 3                          https://www.ironhack.com/
# 4      https://blog.ironhack.com/category/madrid-en/
# 5    https://blog.ironhack.com/es/madrid-2-2/page/3/
# 6  https://blog.ironhack.com/es/campus-de-madrid/...
# 7   https://blog.ironhack.com/es/madrid-2-2/page/10/
# 8  https://blog.ironhack.com/es/campus-de-madrid/...
# 9  https://blog.ironhack.com/es/campus-de-madrid/...
#
#                                              snippet  \
# 0  Enjoy a guided tour and discover some of the m...
# 1  Jan 18, 2019 ... Our alumni Elise tells you al...
# 2  Formez vous sur Madrid en Développement Web ou...
# 3  Learn to code and UX/UI design through one of ...
# 4  Dec 3, 2018 ... Our latest articles Inside Cab...
# 5  In May this year, I was at a point in my life ...
# 6  In May this year, I was at a point in my life ...
# 7  Building.co is a collaborative workspace that ...
# 8  First impressions count, and the window in whi...
# 9  Jimmy: Alright, so we are recording. Welcome b...
#
#                                                title
# 0                             Ironhack Alumni Summit
# 1                             Madrid | Ironhack Blog
# 2  Ironhack Madrid - Bootcamps en Développement W...
# 3  Ironhack Web Development Bootcamp & UX/UI Desi...
# 4                    Madrid Archives - Ironhack Blog
# 5                        Madrid (ES) | Ironhack Blog
# 6                   Campus de Madrid - Ironhack Blog
# 7                        Madrid (ES) | Ironhack Blog
# 8                   Campus de Madrid - Ironhack Blog
# 9                   Campus de Madrid - Ironhack Blog

# %%
params_miami = {
    "key": "AIzaSyDeDEXWk7bq0r0GYzz-Pmc6dWqRGVxJ2Zc",
    "cx": "003240156206868727193:scrr7eqktoy",
    "fields": "kind,items(title,link,snippet),queries(request(title,totalResults,count,startIndex))",
    "q": "miami",
    "start": 1
}

# %%
data_miami = requests.get(google_api, params=params_miami).json()

# %%
data_miami
# Out:
# {'kind': 'customsearch#search',
#  'queries': {'request': [{'title': 'Google Custom Search - miami',
#     'totalResults': '1570',
#     'count': 10,
#     'startIndex': 1}]},
#  'items': [{'title': 'Ironhack Web Development Bootcamp & UX/UI Design Bootcamp',
#    'link': 'https://www.ironhack.com/',
#    'snippet': '... of our full time or part time courses. Web Development Bootcamp and UX/UI \nDesign Bootcamp in Madrid, Barcelona, Miami, Paris, Mexico City, Berlin, Bogotá\n,\xa0...'},
#   {'title': 'Ironhack - Bootcamps and Courses in Web Coding and UX/UI Design',
#    'link': 'https://www.ironhack.com/en/web-barcelona-14',
#    'snippet': 'Amsterdam Barcelona Berlin Bogotá Lisbon Madrid Mexico City Miami Munich \nParis São Paulo · Ironhack Logo 990 Biscayne Blvd. Ste 503 - Miami FL 33132'},
#   {'title': 'Miami (EN) | Ironhack Blog',
#    'link': 'https://blog.ironhack.com/locations-miami/',
#    'snippet': 'He has gone on to work as a developer in the South Florida Tech industry. \nRecently, Ariel placed 2nd at the Miami Bitcoin Hackathon. (Check out his project\n\xa0...'},
#   {'title': 'Miami Archives - Ironhack Blog',
#    'link': 'https://blog.ironhack.com/category/miami-en/',
#    'snippet': 'He has gone on to work as a developer in the South Florida Tech industry. \nRecently, Ariel placed 2nd at the Miami Bitcoin Hackathon. (Check out his project\n\xa0...'},
#   {'title': 'Miami (EN) | Ironhack Blog',
#    'link': 'https://blog.ironhack.com/locations-miami/page/2/',
#    'snippet': 'No Results Found. The page you requested could not be found. Try refining your \nsearch, or use the navigation above to locate the post.'},
#   {'title': 'Web Development Bootcamp',
#    'link': 'https://code.ironhack.com/web-dev-bootcamp-en-sem-mia/',
#    'snippet': 'Career Support. Career Support. 120 SW 8th St. Miami, Fl 33130. +1-954-398-\n5044 EOM. mia@ironhack.com. Full-Time and In-person Coding Bootcamp\xa0...'},
#   {'title': 'Curso de Data Analytics en Miami | Bootcamp de 9 Semanas ...',
#    'link': 'https://www.ironhack.com/es/cursos/data-analytics-bootcamp',
#    'snippet': 'Después de 9 semanas de trabajo intensivo en el curso de análisis de datos, los \nalumnos de Ironhack se gradúan como analistas de datos junior full-stack.'},
#   {'title': 'A Virtual Tour of Our Ironhack Miami Campus - Ironhack Blog',
#    'link': 'https://blog.ironhack.com/2016/06/27/a-third-of-ironhack-calls-miami-home/',
#    'snippet': 'Jun 27, 2016 ... Building.co is a collaborative workspace that accommodates local tech \ncompanies; it also happens to be home to the Ironhack Miami campus.'},
#   {'title': 'Curso de UX/UI Design em Miami | Bootcamp de 9 Semanas ...',
#    'link': 'https://www.ironhack.com/pt/cursos/ux-ui-design-bootcamp-learn-ux-design',
#    'snippet': 'Curso de UX design: em 9 semanas aprendes os fundamentos do UX design, do \nUI design e também como produzir bons designs web/móvel para os teus\xa0...'},
#   {'title': 'miami Archives - Ironhack Blog',
#    'link': 'https://blog.ironhack.com/tag/miami-en/',
#    'snippet': 'He has gone on to work as a developer in the South Florida Tech industry. \nRecently, Ariel placed 2nd at the Miami Bitcoin Hackathon. (Check out his project\n\xa0...'}]}

# %%
events_miami = pd.DataFrame(data_miami['items'])

# %%
events_miami.sort_values(by='snippet')
# Out:
#                                                 link  \
# 0                          https://www.ironhack.com/
# 1       https://www.ironhack.com/en/web-barcelona-14
# 5  https://code.ironhack.com/web-dev-bootcamp-en-...
# 8  https://www.ironhack.com/pt/cursos/ux-ui-desig...
# 6  https://www.ironhack.com/es/cursos/data-analyt...
# 2         https://blog.ironhack.com/locations-miami/
# 3       https://blog.ironhack.com/category/miami-en/
# 9            https://blog.ironhack.com/tag/miami-en/
# 7  https://blog.ironhack.com/2016/06/27/a-third-o...
# 4  https://blog.ironhack.com/locations-miami/page/2/
#
#                                              snippet  \
# 0  ... of our full time or part time courses. Web...
# 1  Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 5  Career Support. Career Support. 120 SW 8th St....
# 8  Curso de UX design: em 9 semanas aprendes os f...
# 6  Después de 9 semanas de trabajo intensivo en e...
# 2  He has gone on to work as a developer in the S...
# 3  He has gone on to work as a developer in the S...
# 9  He has gone on to work as a developer in the S...
# 7  Jun 27, 2016 ... Building.co is a collaborativ...
# 4  No Results Found. The page you requested could...
#
#                                                title
# 0  Ironhack Web Development Bootcamp & UX/UI Desi...
# 1  Ironhack - Bootcamps and Courses in Web Coding...
# 5                           Web Development Bootcamp
# 8  Curso de UX/UI Design em Miami | Bootcamp de 9...
# 6  Curso de Data Analytics en Miami | Bootcamp de...
# 2                         Miami (EN) | Ironhack Blog
# 3                     Miami Archives - Ironhack Blog
# 9                     miami Archives - Ironhack Blog
# 7  A Virtual Tour of Our Ironhack Miami Campus - ...
# 4                         Miami (EN) | Ironhack Blog

# %%
events_miami.groupby(['snippet']).count()
# Out:
#                                                     link  title
# snippet
# ... of our full time or part time courses. Web ...     1      1
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid...     1      1
# Career Support. Career Support. 120 SW 8th St. ...     1      1
# Curso de UX design: em 9 semanas aprendes os fu...     1      1
# Después de 9 semanas de trabajo intensivo en el...     1      1
# He has gone on to work as a developer in the So...     3      3
# Jun 27, 2016 ... Building.co is a collaborative...     1      1
# No Results Found. The page you requested could ...     1      1

# %%
cities = ['Amsterdam', 'Barcelona', 'Berlin', 'Bogotá',  'Lisbon', 'Madrid', 'Mexico City', 'Miami', 'Munich','Paris', 'São Paolo' ]

# %%
all_cities_df = pd.DataFrame()
for city in cities:
    print(city)
    params = {
    "key": "AIzaSyDeDEXWk7bq0r0GYzz-Pmc6dWqRGVxJ2Zc",
    "cx": "003240156206868727193:scrr7eqktoy",
    "fields": "kind,items(title,link,snippet),queries(request(title,totalResults,count,startIndex))",
    "q": city.lower(),
    "start": 1
    }
    data = requests.get(google_api, params=params).json()
    dataframe = pd.DataFrame(data['items'])
    dataframe['city'] = city
    print(dataframe[['link']].head(1))
    all_cities_df = all_cities_df.append(dataframe,ignore_index=True)
    print(all_cities_df.head(1))
# Out:
# Amsterdam
#                                              link
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Barcelona
#                                            link
# 0  https://www.ironhack.com/en/web-barcelona-14
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Berlin
#                                           link
# 0  https://blog.ironhack.com/locations-berlin/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Bogotá
#                                           link
# 0  https://www.ironhack.com/nl/locaties/bogota
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Lisbon
#                                        link
# 0  https://code.ironhack.com/wecode-lisbon/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Madrid
#                            link
# 0  https://summit.ironhack.com/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Mexico City
#                                link
# 0  https://www.ironhack.com/en/team
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Miami
#                         link
# 0  https://www.ironhack.com/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Munich
#                                            link
# 0  https://www.ironhack.com/en/locations/munich
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# Paris
#                                          link
# 0  https://blog.ironhack.com/locations-paris/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# São Paolo
#                                              link
# 0  https://blog.ironhack.com/locations-sao-paolo/
#                                              link  \
# 0  https://code.ironhack.com/iamcoding-amsterdam/
#
#                                              snippet  \
# 0  For a whole day, you'll immerse yourself in th...
#
#                                         title       city
# 0  I AM CODING - Ironhack Amsterdam workshops  Amsterdam

# %%
all_cities_df.groupby('snippet').count().sort_values(by='link', ascending=False)
# Out:
#                                                                 link  title
# snippet                                            city
# He has gone on to work as a developer in the So... Miami           3      3
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Bogotá          2      2
# In May this year, I was at a point in my life t... Madrid          2      2
# Feb 6, 2019 ... Ironhack is a global tech schoo... Mexico City     2      2
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Bogotá          2      2
#                                                    Munich          2      2
# Jan 18, 2019 ... Organizer. Ironhack Amsterdam.... Amsterdam       2      2
# Join Ironhack. Do you want to study at Ironhack... Barcelona       2      2
# Join Ironhack. Do you want to study at Ironhack... Berlin          2      2
# Ironhack is a global tech school with campuses ... Mexico City     2      2
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Munich          2      2
#                                                    Mexico City     2      2
# Mexico City · Berlin · Amsterdam · São Paulo. L... Berlin          2      2
# ... time courses. Web Development Bootcamp and ... Munich          2      2
# Thor completed the Web Development Bootcamp in ... Barcelona       2      2
# In May this year, I was at a point in my life t... Lisbon          1      1
#                                                    Barcelona       1      1
# I find myself at a coding school called Ironhac... Mexico City     1      1
# Ironhack is an international school with course... Mexico City     1      1
#                                                    Paris           1      1
# Jan 10, 2019 ... Our latest articles How coding... Barcelona       1      1
# I don't really know how to describe by time at ... Lisbon          1      1
# Jan 18, 2019 ... ... General · Lisbon · Madrid ... São Paolo       1      1
# Formez vous sur Madrid en Développement Web ou ... Madrid          1      1
# For a whole day, you'll immerse yourself in the... Amsterdam       1      1
# For a whole day, you'll immerse yourself in the... Amsterdam       1      1
# Jan 18, 2019 ... Our alumni Elise tells you all... Madrid          1      1
# Ironhack is a global tech school with campuses ... Barcelona       1      1
# ... A PRÓXIMA GERAÇÃO DE CRIADORES DIGITAIS EM.... São Paolo       1      1
# Jan 18, 2019 ... Our latest articles [Testimoni... Paris           1      1
# ...                                                              ...    ...
# 10 set. 2018 ... Mas algumas perguntas muito co... São Paolo       1      1
# ... of our full time or part time courses. Web ... Paris           1      1
#                                                    Miami           1      1
#                                                    Mexico City     1      1
#                                                    Berlin          1      1
#                                                    Barcelona       1      1
# ... abiertas) – Come Visit us! Ironhack Campus ... Paris           1      1
# Amsterdam Barcelona Berlim Bogotá Lisbon Madrid... Bogotá          1      1
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Barcelona       1      1
# Feb 1, 2019 ... Organizer. Ironhack Amsterdam. ... Amsterdam       1      1
# Dec 20, 2016 ... Marc, our fearless campus mana... Barcelona       1      1
# ... Design grâce à nos cours à temps plein ou p... Paris           1      1
# Después de 9 semanas de trabajo intensivo en el... Miami           1      1
# Descubra as tendências que você, desenvolvedor ... São Paolo       1      1
# Dec 4, 2018 ... Organizer. Ironhack Berlin - Co... Berlin          1      1
# Dec 3, 2018 ... PREPARING THE NEXT GENERATION O... Mexico City     1      1
# Dec 3, 2018 ... Our latest articles Inside Cabi... Madrid          1      1
# Dec 20, 2018 ... In May this year, I was at a p... Amsterdam       1      1
# Dec 20, 2018 ... From architecture to UX/UI Des... Amsterdam       1      1
# Curso de UX design: em 9 semanas aprendes os fu... Miami           1      1
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Berlin          1      1
# Career Support. Career Support. 120 SW 8th St. ... Miami           1      1
# Building.co is a collaborative workspace that a... Madrid          1      1
# Barcelona Campus. 2/5. Prev Next. Ironhack Barc... Bogotá          1      1
# Apr 12, 2016 ... The Ironhack Hackshow is the m... Lisbon          1      1
# Amsterdam Barcelone Berlin Bogotá Lisbon Madrid... Munich          1      1
# Amsterdam Barcelona Berlin Bogotá Lisbon Madrid... Paris           1      1
#                                                    Miami           1      1
#                                                    Lisbon          1      1
# por Pedro Falkenbach | Wednesday, February 13, ... São Paolo       1      1
#
# [94 rows x 2 columns]

# %%
cities_sql= """
CREATE TABLE `cities` (
  `id` smallint(5) unsigned NOT NULL AUTO_INCREMENT,
  `name` varchar(45) NOT NULL,
  PRIMARY KEY (`id`)
  
) ENGINE=InnoDB AUTO_INCREMENT=201 DEFAULT CHARSET=utf8;"""

# %%
events_sql="""
CREATE TABLE `events` (
  `id` smallint(5) unsigned NOT NULL AUTO_INCREMENT,
  `title` varchar(45) NOT NULL,
  `link` varchar(45) NOT NULL,
  `snippet` varchar(45) NOT NULL,
  `city_id` smallint(5) unsigned NOT NULL,
  PRIMARY KEY (`id`),
  CONSTRAINT `fk_city_id` FOREIGN KEY (`city_id`) REFERENCES `cities` (`id`) 
  
) ENGINE=InnoDB AUTO_INCREMENT=201 DEFAULT CHARSET=utf8;"""

# %%
cities_df = all_cities_df.groupby("city").count().reset_index()[['city']]

# %%
cities_df.rename(columns={'city':'name'}, inplace=True)

# %%
cities_df.reset_index(inplace=True)

# %%
cities_df.to_sql(name=cities, con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-17357756c15b> in <module>
# ----> 1 cities_df.to_sql(name=cities, con=engine, if_exists='append', index=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1123         table = SQLTable(name, self, frame=frame, index=index,
#    1124                          if_exists=if_exists, index_label=index_label,
# -> 1125                          schema=schema, dtype=dtype)
#    1126         table.create()
#    1127         table.insert(chunksize)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in __init__(self, name, pandas_sql_engine, frame, index, if_exists, prefix, index_label, schema, keys, dtype)
#     538         if frame is not None:
#     539             # We want to initialize based on a dataframe
# --> 540             self.table = self._create_table_setup()
#     541         else:
#     542             # no data provided, read-only mode
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _create_table_setup(self)
#     763         meta = MetaData(self.pd_sql, schema=schema)
#     764
# --> 765         return Table(self.name, meta, *columns, schema=schema)
#     766
#     767     def _harmonize_columns(self, parse_dates=None):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     430         mustexist = kw.pop('mustexist', False)
#     431         key = _get_table_key(name, schema)
# --> 432         if key in metadata.tables:
#     433             if not keep_existing and not extend_existing and bool(args):
#     434                 raise exc.InvalidRequestError(
#
# TypeError: unhashable type: 'list'

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://ironhacker_read:ir0nhack3r@35.239.232.23/ironhack_events')

# %%
cities_df
# Out:
#            city
# 0     Amsterdam
# 1     Barcelona
# 2        Berlin
# 3        Bogotá
# 4        Lisbon
# 5        Madrid
# 6   Mexico City
# 7         Miami
# 8        Munich
# 9         Paris
# 10    São Paolo

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='35.239.232.23', database='ironhack_events', user='ironhacker_read', password='ir0nhack3r')

# %%
cursor = conn.cursor()

# %%
insert_sql= '''
INSERT INTO cities (name) VALUES '''

# %%
cursor.execute()

# %%
insert_sql= '''
INSERT INTO cities (name) VALUES '''

for city in set(all_cities_df.city):
    row_sql = f"('{city}'), "
    insert_sql += row_sql
    print(insert_sql)
insert_sql = insert_sql[:-2]
# Out:
# INSERT INTO cities (name) VALUES ('São Paolo'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'), ('Bogotá'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'), ('Bogotá'), ('Munich'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'), ('Bogotá'), ('Munich'), ('Amsterdam'),
#
# INSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'), ('Bogotá'), ('Munich'), ('Amsterdam'), ('Berlin'),

# %%
insert_sql
# Out:
# "\nINSERT INTO cities (name) VALUES ('São Paolo'), ('Miami'), ('Mexico City'), ('Paris'), ('Madrid'), ('Barcelona'), ('Lisbon'), ('Bogotá'), ('Munich'), ('Amsterdam'), ('Berlin')"

# %%
cursor.execute(insert_sql)

# %%
conn.commit()

# %%
all_cities_df(name='events', engine)
# Out:
#                                                   link  \
# 0       https://code.ironhack.com/iamcoding-amsterdam/
# 1        http://blog.ironhack.com/locations-amsterdam/
# 2         https://code.ironhack.com/iamuxui-amsterdam/
# 3        https://blog.ironhack.com/category/amsterdam/
# 4                            https://www.ironhack.com/
# 5    https://blog.ironhack.com/wp-event/dive-into-u...
# 6    https://blog.ironhack.com/wp-event/i-am-coding...
# 7                     https://www.ironhack.com/en/team
# 8          https://www.ironhack.com/nl/locaties/bogota
# 9    https://blog.ironhack.com/wp-event/ironhack-op...
# 10        https://www.ironhack.com/en/web-barcelona-14
# 11                           https://www.ironhack.com/
# 12      https://blog.ironhack.com/locations-barcelona/
# 13    https://blog.ironhack.com/category/barcelona-en/
# 14      https://www.ironhack.com/nl/locaties/barcelona
# 15        https://www.ironhack.com/br/locais/barcelona
# 16   https://blog.ironhack.com/es/locations-barcelo...
# 17   https://blog.ironhack.com/2016/12/20/coding-bo...
# 18   https://blog.ironhack.com/es/locations-barcelo...
# 19   https://blog.ironhack.com/es/campus-de-barcelo...
# 20         https://blog.ironhack.com/locations-berlin/
# 21        https://www.ironhack.com/de/standorte/berlin
# 22          https://blog.ironhack.com/category/berlin/
# 23                           https://www.ironhack.com/
# 24                    https://www.ironhack.com/en/team
# 25        https://www.ironhack.com/en/web-barcelona-14
# 26   https://blog.ironhack.com/wp-event/time-for-ir...
# 27           https://www.ironhack.com/br/locais/berlin
# 28                          https://blog.ironhack.com/
# 29   https://blog.ironhack.com/page/2/?wordfence_lh...
# ..                                                 ...
# 80        https://www.ironhack.com/en/locations/munich
# 81           https://www.ironhack.com/fr/campus/munich
# 82        https://www.ironhack.com/en/web-barcelona-14
# 83         https://www.ironhack.com/nl/locaties/bogota
# 84                    https://www.ironhack.com/en/team
# 85            https://www.ironhack.com/en/legal-notice
# 86           https://www.ironhack.com/fr/campus/madrid
# 87        https://www.ironhack.com/de/standorte/berlin
# 88           https://www.ironhack.com/br/locais/berlin
# 89         https://www.ironhack.com/de/standorte/paris
# 90          https://blog.ironhack.com/locations-paris/
# 91           https://blog.ironhack.com/category/paris/
# 92                           https://www.ironhack.com/
# 93         https://www.ironhack.com/de/standorte/paris
# 94                    https://www.ironhack.com/en/team
# 95                         https://www.ironhack.com/fr
# 96     https://code.ironhack.com/web-dev-fr-sem-paris/
# 97            https://blog.ironhack.com/author/thomas/
# 98        https://www.ironhack.com/en/web-barcelona-14
# 99   https://blog.ironhack.com/page/3/?wordfence_lh...
# 100     https://blog.ironhack.com/locations-sao-paolo/
# 101  https://blog.ironhack.com/br/category/sao-paol...
# 102  http://blog.ironhack.com/pt/category/sao-paolo...
# 103  https://blog.ironhack.com/br/category/sao-paol...
# 104                http://blog.ironhack.com/br/page/5/
# 105  https://blog.ironhack.com/br/category/web-deve...
# 106        https://blog.ironhack.com/br/home-5/page/3/
# 107  https://blog.ironhack.com/br/category/sao-paul...
# 108           https://blog.ironhack.com/author/thomas/
# 109  https://blog.ironhack.com/br/category/sao-paul...
#
#                                                snippet  \
# 0    For a whole day, you'll immerse yourself in th...
# 1    Dec 20, 2018 ... In May this year, I was at a ...
# 2    For a whole day, you'll immerse yourself in th...
# 3    Dec 20, 2018 ... From architecture to UX/UI De...
# 4    Learn to code and UX/UI design through one of ...
# 5    Feb 1, 2019 ... Organizer. Ironhack Amsterdam....
# 6    Jan 18, 2019 ... Organizer. Ironhack Amsterdam...
# 7    2018 Campus Amsterdam. 2018 Campus São Paulo. ...
# 8    Amsterdam Barcelona Berlijn Bogotá Lisbon Madr...
# 9    Jan 18, 2019 ... Organizer. Ironhack Amsterdam...
# 10   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 11   ... of our full time or part time courses. Web...
# 12   Thor completed the Web Development Bootcamp in...
# 13   Jan 10, 2019 ... Our latest articles How codin...
# 14   Join Ironhack. Do you want to study at Ironhac...
# 15   Join Ironhack. Do you want to study at Ironhac...
# 16   Ironhack is a global tech school with campuses...
# 17   Dec 20, 2016 ... Marc, our fearless campus man...
# 18   Thor completed the Web Development Bootcamp in...
# 19   In May this year, I was at a point in my life ...
# 20   Jan 30, 2019 ... The future of work is digital...
# 21   Join Ironhack. Do you want to study at Ironhac...
# 22   Jan 30, 2019 ... Our latest articles Coding Bo...
# 23   ... of our full time or part time courses. Web...
# 24   2018 Campus Berlin. 2018 Campus Amsterdam. 201...
# 25   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 26   Dec 4, 2018 ... Organizer. Ironhack Berlin - C...
# 27   Join Ironhack. Do you want to study at Ironhac...
# 28   Mexico City · Berlin · Amsterdam · São Paulo. ...
# 29   Mexico City · Berlin · Amsterdam · São Paulo. ...
# ..                                                 ...
# 80   ... time courses. Web Development Bootcamp and...
# 81   ... time courses. Web Development Bootcamp and...
# 82   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 83   Amsterdam Barcelona Berlijn Bogotá Lisbon Madr...
# 84   2018 Campus Amsterdam. 2018 Campus São Paulo. ...
# 85   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 86   Amsterdam Barcelone Berlin Bogotá Lisbon Madri...
# 87   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 88   Amsterdam Barcelona Berlim Bogotá Lisbon Madri...
# 89   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 90   Nobody can improvise himself as a data profess...
# 91   Jan 18, 2019 ... Our latest articles [Testimon...
# 92   ... of our full time or part time courses. Web...
# 93   Join Ironhack. Do you want to study at Ironhac...
# 94   Ironhack is an international school with cours...
# 95   ... Design grâce à nos cours à temps plein ou ...
# 96   Vous avez besoin d'une transition professionne...
# 97   Jan 18, 2019 ... by Thomas Jacquesson | Friday...
# 98   Amsterdam Barcelona Berlin Bogotá Lisbon Madri...
# 99   ... abiertas) – Come Visit us! Ironhack Campus...
# 100  No Results Found. The page you requested could...
# 101  por Pedro Falkenbach | Friday, November 30, 20...
# 102  by Alberto Marcos | Wednesday, September 19, 2...
# 103  10 set. 2018 ... Mas algumas perguntas muito c...
# 104  Mateus Félix é um Teacher Assistant na Ironhac...
# 105  por Pedro Falkenbach | Wednesday, February 13,...
# 106  ... A PRÓXIMA GERAÇÃO DE CRIADORES DIGITAIS EM...
# 107  Descubra as tendências que você, desenvolvedor...
# 108  Jan 18, 2019 ... ... General · Lisbon · Madrid...
# 109  13 fev. 2019 ... Como você pode mudar a sua vi...
#
#                                                  title       city
# 0           I AM CODING - Ironhack Amsterdam workshops  Amsterdam
# 1                            Amsterdam | Ironhack Blog  Amsterdam
# 2            I AM UX/UI - Ironhack Amsterdam workshops  Amsterdam
# 3                   Amsterdam Archives - Ironhack Blog  Amsterdam
# 4    Ironhack Web Development Bootcamp & UX/UI Desi...  Amsterdam
# 5    Dive into UI Design: design a cheesy Valentine...  Amsterdam
# 6    I am Coding: Intro to Web Development for begi...  Amsterdam
# 7                               Meet the Ironhack Team  Amsterdam
# 8    Ironhack Bogotá Web Development & UX/UI Design...  Amsterdam
# 9                  Ironhack Open House - Ironhack Blog  Amsterdam
# 10   Ironhack - Bootcamps and Courses in Web Coding...  Barcelona
# 11   Ironhack Web Development Bootcamp & UX/UI Desi...  Barcelona
# 12                      Barcelona (EN) - Ironhack Blog  Barcelona
# 13                  Barcelona Archives - Ironhack Blog  Barcelona
# 14   Ironhack Barcelona Web Development & UX/UI Des...  Barcelona
# 15                                           Barcelona  Barcelona
# 16                      Barcelona (ES) | Ironhack Blog  Barcelona
# 17   Coding Bootcamp Graduation - Ironhack's Barcel...  Barcelona
# 18                      Barcelona (ES) | Ironhack Blog  Barcelona
# 19                 Campus de Barcelona - Ironhack Blog  Barcelona
# 20                         Berlin (EN) - Ironhack Blog     Berlin
# 21   Ironhack Berlin Webentwicklungs- und UX/UI-Des...     Berlin
# 22                     Berlin Archives - Ironhack Blog     Berlin
# 23   Ironhack Web Development Bootcamp & UX/UI Desi...     Berlin
# 24                              Meet the Ironhack Team     Berlin
# 25   Ironhack - Bootcamps and Courses in Web Coding...     Berlin
# 26   Time for Ironhack's big HACKSHOW   - Ironhack ...     Berlin
# 27   Bootcamps de Desenvolvimento Web & UX/UI Desig...     Berlin
# 28                            Ironhack Blog: Home (EN)     Berlin
# 29                           Home (EN) - Ironhack Blog     Berlin
# ..                                                 ...        ...
# 80                                              Munich     Munich
# 81   Ironhack Web Development Bootcamp & UX/UI Desi...     Munich
# 82   Ironhack - Bootcamps and Courses in Web Coding...     Munich
# 83   Ironhack Bogotá Web Development & UX/UI Design...     Munich
# 84                              Meet the Ironhack Team     Munich
# 85        Development Bootcamp Legal notice | Ironhack     Munich
# 86   Ironhack Madrid - Bootcamps en Développement W...     Munich
# 87   Ironhack Berlin Webentwicklungs- und UX/UI-Des...     Munich
# 88   Bootcamps de Desenvolvimento Web & UX/UI Desig...     Munich
# 89   Ironhack Paris Webentwicklungs- und UX/UI-Desi...     Munich
# 90                          Paris (EN) - Ironhack Blog      Paris
# 91                      Paris Archives - Ironhack Blog      Paris
# 92   Ironhack Web Development Bootcamp & UX/UI Desi...      Paris
# 93   Ironhack Paris Webentwicklungs- und UX/UI-Desi...      Paris
# 94                              Meet the Ironhack Team      Paris
# 95   Ironhack Tech School: Cours intensifs en Dével...      Paris
# 96                      Campus en plein coeur de Paris      Paris
# 97          Thomas Jacquesson, Author at Ironhack Blog      Paris
# 98   Ironhack - Bootcamps and Courses in Web Coding...      Paris
# 99                           Home (EN) - Ironhack Blog      Paris
# 100                     São Paulo (EN) - Ironhack Blog  São Paolo
# 101                 São Paolo Archives - Ironhack Blog  São Paolo
# 102                          São Paolo | Ironhack Blog  São Paolo
# 103                          São Paolo | Ironhack Blog  São Paolo
# 104                     São Paulo HOME | Ironhack Blog  São Paolo
# 105           Web Development Archives - Ironhack Blog  São Paolo
# 106                          HOME (BR) | Ironhack Blog  São Paolo
# 107                 Sao Paulo Archives - Ironhack Blog  São Paolo
# 108         Thomas Jacquesson, Author at Ironhack Blog  São Paolo
# 109  Sao Paulo Archives - Página 2 de 2 - Ironhack ...  São Paolo
#
# [110 rows x 4 columns]
